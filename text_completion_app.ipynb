# %%
from transformers import pipeline

generator = pipeline("text-generation", model= "gpt2")

while True:
    prompt = input("Enter prompt: ")
    if prompt == "exit":
        break
    result = generator(prompt, max_length =50 , temperature= 0.7)
    print ("Generated text: ", result[0]['generated_text'])
# Out:
# Device set to use mps:0
# Enter prompt:  Describe a new color that humans have never seen before.
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated text:  Describe a new color that humans have never seen before.
#
# The color is very complex like the color of a flower, but it's one of those things where it's the only thing you really have to know. It's like a puzzle. It's not really what you'd expect, but it's what you'll make it out to be.
#
# We were in the lab for 10 minutes at the end of that day, and we had one of these tiny tubes that were on the floor of our lab. We had about a dozen of these small tubes, and we kept going through them and trying to get a solid color. We were like, "Oh my gosh, this is amazing," and they were like, "Oh my gosh, this is amazing." At one point, we were like, "What? Oh my gosh, this is amazing." They were like, "Oh my gosh, this is amazing." That was the first time we ever had this amazing color.
#
# I was like, "Oh my gosh, this is amazing."
#
# A lot of color is created by the way that we're able to use our imagination. You know, we're not really able to imagine that, but it's very clear to us. So we would always try and think
# Enter prompt:  Teach me what black holes are, but only using cooking metaphors.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated text:  Teach me what black holes are, but only using cooking metaphors.
#
# The book was really good. The book was actually very good. There were other problems with it, but I wanted to address them.
#
# What you really need is a basic knowledge of what black holes are. So, how does a black hole work?
#
# I think the basic idea of black holes is that they are so dense that they are invisible. That's why they are so tiny. They are so tiny because they are so far away. So, there are an infinite number of black holes around them, there are so many possibilities. They are so massive. But their light travels at the speed of light. So, there's no way to know what that means.
#
# And that's where you start to see the possibility of black holes.
#
# The concept of black holes is that they are so small that they are not visible to other things. They are very small. They are so small that they have no shape to them. It's not like you can see them in the sky or in the rain. It's like, they're there, they're not there.
#
# I think that we should think about black holes not as black holes, but as black holes.
#
# There are black holes, but the main issue
# Enter prompt:  Write a Python function that generate random haikus using a list of words.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated text:  Write a Python function that generate random haikus using a list of words.
#
# from haikus import random import random rand = random.randrange(3, 3) for word in word: for word in word.iteritems(): # Create a random haikus list for word in word: for word in word.iteritems(): # Generate random haikus for word in word: print 'Hello, world!' end
#
# This generates a haikus list, which is now a bunch of strings, and the random haikus that it generates. If you don't specify any values, the generator will automatically generate the random haikus, which is what you should do. Here's an example of how to do two things by hand. First, you have to write a function that adds random haikus to the string, and then give the string a random number.
#
# from haikus import random import random import time import time.sleep import time.timezone import random import time.timezone_safe as u def add_random(word1, word2, word3, word4): random.random.randrange(3, 3) for word in word1: for word in word2: print 'Hello, world!' print 'Hello, world!' end
#
# And
# Enter prompt:  You're an old wizard living in a mounting, I ask: What is the meaning of life?
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated text:  You're an old wizard living in a mounting, I ask: What is the meaning of life?
#
# The answer is: It's a question that is not answered.
#
# For a long time, I have been thinking about this question. How do we get there? How do we avoid the pitfalls of the past? How do we overcome the challenges of the present?
#
# I have a theory for this.
#
# I believe that the answer lies in our ability to think deeply and to seek out the answers that help us to understand the world.
#
# I believe that we are the ones who should be most open to the possibilities that lie ahead. We must not only look for the answers we find, but to see how they can help us to change the world.
#
# That is what I am trying to do.
#
# I believe that most people can choose to have a life that is unique, beautiful, and enjoyable.
#
# That is my ideal. I believe that our life is unique, beautiful, and enjoyable. It is not only about being a smart, good person, but also about having a deep, loving, positive, and hopeful heart.
#
# I believe that we can use the life we have to change our world.
#
# I believe that life is the single greatest form of human development.
#
# I believe that we
# Enter prompt:  If time could talk, would it say to humanity?
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated text:  If time could talk, would it say to humanity?
#
# If time could speak, would it say to humanity?
#
# I could die.
#
# Then how could it say to humanity?
#
# I could die.
#
# How could it say to humanity?
#
# I could die.
#
# If time could speak, would it say to humanity?
#
# I could die.
#
# If time could speak, would it say to humanity?
#
# I could die.
#
# If time could speak, would it say to humanity?
#
# I could die.
#
# When did I die?
#
# When did I die?
#
# I can't die.
#
# And I can't die.
#
# I can't die.
#
# And I can't die.
#
# When did I die?
#
# When did I die?
#
# I can't die.
#
# And I can't die.
#
# Hearing a voice speak, I could die.
#
# I could die.
#
# I could die.
#
# I can't die.
#
# Then how could it say to humanity?
#
# I could die.
#
# I could die.
#
# How could it say to humanity?
#
# I could die.
#
# I could die.
# Enter prompt:  exit
